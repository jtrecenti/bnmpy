# %%
from bnmpy import BNMPAPIClient, load_cookies

cookies, fingerprint = load_cookies("../cookies.json")
client = BNMPAPIClient(cookies=cookies, fingerprint=fingerprint)

# Make the API call
response = client.pesquisa_pecas_filter(
    busca_orgao_recursivo=False,
    orgao_expeditor={},
    id_estado=2,
    page=0,
    size=10
)

data = response.json()

# %%
data
# Out:
# {'content': [{'id': 136761212,
#    'numeroPeca': '0000218262008802003110000126',
#    'numeroProcesso': '00002182620088020031',
#    'nomePessoa': 'Júlio Cezar Garcia',
#    'alcunha': 'Não Informado',
#    'descricaoStatus': 'Pendente de Cumprimento',
#    'dataExpedicao': '2020-01-28',
#    'nomeOrgao': 'VARA DO ÚNICO OFÍCIO DE PASSO DE CAMARAGIBE',
#    'descricaoPeca': 'Mandado de Internação',
#    'idTipoPeca': 10,
#    'nomeMae': 'Não declarada',
#    'nomePai': 'José Ramos Garcia',
#    'descricaoSexo': 'Masculino',
#    'descricaoProfissao': 'Não informado',
#    'dataNascimento': '1983-04-07',
#    'numeroPecaAnterior': None,
#    'numeroPecaFormatado': '0000218-26.2008.8.02.0031.10.0001-26',
#    'dataNascimentoFormatada': '07/04/1983',
#    'dataExpedicaoFormatada': '28/01/2020'},
#   {'id': 25926466,
#    'numeroPeca': '0500013942009802003310000126',
#    'numeroProcesso': '05000139420098020033',
#    'nomePessoa': 'José Rodrigues do Nascimento',
#    'alcunha': 'Não informado',
#    'descricaoStatus': 'Pendente de Cumprimento',
#    'dataExpedicao': '2018-04-19',
#    'nomeOrgao': '16ª VARA CRIMINAL DA CAPITAL / EXECUÇÕES PENAIS',
#    'descricaoPeca': 'Mandado de Internação',
#    'idTipoPeca': 10,
#    'nomeMae': 'Não informado',
#    'nomePai': 'Não informado',
#    'descricaoSexo': 'Masculino',
#    'descricaoProfissao': 'Não informado',
#    'dataNascimento': None,
#    'numeroPecaAnterior': None,
#    'numeroPecaFormatado': '0500013-94.2009.8.02.0033.10.0001-26',
#    'dataNascimentoFormatada': ' ',
#    'dataExpedicaoFormatada': '19/04/2018'},
#   {'id': 163826712,
#    'numeroPeca': '0700345622015802006710000104',
#    'numeroProcesso': '07003456220158020067',
#    'nomePessoa': 'Emerson Cardoso dos Santos',
#    'alcunha': 'Bracinho',
#    'descricaoStatus': 'Pendente de Cumprimento',
#    'dataExpedicao': '2021-05-06',
#    'nomeOrgao': '12ª VARA CRIMINAL DA CAPITAL',
#    'descricaoPeca': 'Mandado de Internação',
#    'idTipoPeca': 10,
#    'nomeMae': 'MARIA JOSE DOS SANTOS',
#    'nomePai': 'Não Informado',
#    'descricaoSexo': 'Masculino',
#    'descricaoProfissao': 'Não informado',
#    'dataNascimento': '1995-07-10',
#    'numeroPecaAnterior': None,
#    'numeroPecaFormatado': '0700345-62.2015.8.02.0067.10.0001-04',
#    'dataNascimentoFormatada': '10/07/1995',
#    'dataExpedicaoFormatada': '06/05/2021'},
#   {'id': 192593469,
#    'numeroPeca': '0700303472022802004110000102',
#    'numeroProcesso': '07003034720228020041',
#    'nomePessoa': 'Pedro da Silva Barros',
#    'alcunha': 'Não informado',
#    'descricaoStatus': 'Pendente de Cumprimento',
#    'dataExpedicao': '2022-10-07',
#    'nomeOrgao': 'VARA DO ÚNICO OFÍCIO DE CAPELA',
#    'descricaoPeca': 'Mandado de Internação',
#    'idTipoPeca': 10,
#    'nomeMae': 'Não informado',
#    'nomePai': 'Não informado',
#    'descricaoSexo': 'Masculino',
#    'descricaoProfissao': 'Não informado',
#    'dataNascimento': None,
#    'numeroPecaAnterior': None,
#    'numeroPecaFormatado': '0700303-47.2022.8.02.0041.10.0001-02',
#    'dataNascimentoFormatada': ' ',
#    'dataExpedicaoFormatada': '07/10/2022'},
#   {'id': 55121334,
#    'numeroPeca': '0000259972010802000610000107',
#    'numeroProcesso': '00002599720108020006',
#    'nomePessoa': 'João Raimundo Bezerra',
#    'alcunha': 'Não Informado',
#    'descricaoStatus': 'Pendente de Cumprimento',
#    'dataExpedicao': '2018-09-04',
#    'nomeOrgao': '16ª VARA CRIMINAL DA CAPITAL / EXECUÇÕES PENAIS',
#    'descricaoPeca': 'Mandado de Internação',
#    'idTipoPeca': 10,
#    'nomeMae': 'Severina Maria Bezerra',
#    'nomePai': 'José Raimundo Bezerra',
#    'descricaoSexo': 'Masculino',
#    'descricaoProfissao': 'Agricultor',
#    'dataNascimento': '1970-02-15',
#    'numeroPecaAnterior': None,
#    'numeroPecaFormatado': '0000259-97.2010.8.02.0006.10.0001-07',
#    'dataNascimentoFormatada': '15/02/1970',
#    'dataExpedicaoFormatada': '04/09/2018'},
#   {'id': 154515360,
#    'numeroPeca': '0800027952020802004010000127',
#    'numeroProcesso': '08000279520208020040',
#    'nomePessoa': 'Kaylane Elane da Silva',
#    'alcunha': 'Não informado',
#    'descricaoStatus': 'Pendente de Cumprimento',
#    'dataExpedicao': '2020-11-16',
#    'nomeOrgao': 'VARA DO ÚNICO OFÍCIO DE ATALAIA',
#    'descricaoPeca': 'Mandado de Internação',
#    'idTipoPeca': 10,
#    'nomeMae': 'Não informado',
#    'nomePai': 'Não informado',
#    'descricaoSexo': 'Feminino',
#    'descricaoProfissao': 'Não informado',
#    'dataNascimento': None,
#    'numeroPecaAnterior': None,
#    'numeroPecaFormatado': '0800027-95.2020.8.02.0040.10.0001-27',
#    'dataNascimentoFormatada': ' ',
#    'dataExpedicaoFormatada': '16/11/2020'},
#   {'id': 122186535,
#    'numeroPeca': '0700236912019802007210000122',
#    'numeroProcesso': '07002369120198020072',
#    'nomePessoa': 'Sebastião Tenório Florentino',
#    'alcunha': 'Não informado',
#    'descricaoStatus': 'Pendente de Cumprimento',
#    'dataExpedicao': '2019-09-01',
#    'nomeOrgao': 'PLANTÃO JUDICIÁRIO DO INTERIOR - 5ª CIRCUNSCRIÇÃO',
#    'descricaoPeca': 'Mandado de Internação',
#    'idTipoPeca': 10,
#    'nomeMae': 'MARIA TENORIO CAVALCANTE FLORENTINO',
#    'nomePai': 'Orlando Tenorio Florentino',
#    'descricaoSexo': 'Masculino',
#    'descricaoProfissao': 'Aposentado',
#    'dataNascimento': '1977-07-05',
#    'numeroPecaAnterior': None,
#    'numeroPecaFormatado': '0700236-91.2019.8.02.0072.10.0001-22',
#    'dataNascimentoFormatada': '05/07/1977',
#    'dataExpedicaoFormatada': '01/09/2019'},
#   {'id': 122533236,
#    'numeroPeca': '0700658352019802005010000212',
#    'numeroProcesso': '07006583520198020050',
#    'nomePessoa': 'Rosilene da Silva',
#    'alcunha': 'Não informado',
#    'descricaoStatus': 'Pendente de Cumprimento',
#    'dataExpedicao': '2019-09-03',
#    'nomeOrgao': '1ª VARA DE PORTO CALVO',
#    'descricaoPeca': 'Mandado de Internação',
#    'idTipoPeca': 10,
#    'nomeMae': 'Josefa Rosa da Silva',
#    'nomePai': 'Não informado',
#    'descricaoSexo': 'Feminino',
#    'descricaoProfissao': 'Desempregado',
#    'dataNascimento': '1983-08-09',
#    'numeroPecaAnterior': None,
#    'numeroPecaFormatado': '0700658-35.2019.8.02.0050.10.0002-12',
#    'dataNascimentoFormatada': '09/08/1983',
#    'dataExpedicaoFormatada': '03/09/2019'},
#   {'id': 192268701,
#    'numeroPeca': '0000072492012802002910000108',
#    'numeroProcesso': '00000724920128020029',
#    'nomePessoa': 'Everaldo Alves de Oliveira',
#    'alcunha': 'Não informado',
#    'descricaoStatus': 'Pendente de Cumprimento',
#    'dataExpedicao': '2022-08-15',
#    'nomeOrgao': 'VARA DO ÚNICO OFÍCIO DO QUEBRANGULO',
#    'descricaoPeca': 'Mandado de Internação',
#    'idTipoPeca': 10,
#    'nomeMae': 'Marinalva Marques da Silva',
#    'nomePai': 'José Everaldo Alves de Oliveira',
#    'descricaoSexo': 'Masculino',
#    'descricaoProfissao': 'Aposentado',
#    'dataNascimento': '1972-01-06',
#    'numeroPecaAnterior': None,
#    'numeroPecaFormatado': '0000072-49.2012.8.02.0029.10.0001-08',
#    'dataNascimentoFormatada': '06/01/1972',
#    'dataExpedicaoFormatada': '15/08/2022'},
#   {'id': 203387672,
#    'numeroPeca': '0701253452025802004310000226',
#    'numeroProcesso': '07012534520258020043',
#    'nomePessoa': 'ANTONIO CARLOS DA CONCEICAO',
#    'alcunha': 'Não Informado',
#    'descricaoStatus': 'Pendente de Cumprimento',
#    'dataExpedicao': '2025-10-13',
#    'nomeOrgao': '2ª VARA DE DELMIRO GOUVEIA / ENTORPECENTES',
#    'descricaoPeca': 'Mandado de Internação',
#    'idTipoPeca': 10,
#    'nomeMae': 'JOVELINA SENHORINHA DA CONCEICAO',
#    'nomePai': 'Não Informado',
#    'descricaoSexo': 'Masculino',
#    'descricaoProfissao': None,
#    'dataNascimento': '1975-01-20',
#    'numeroPecaAnterior': None,
#    'numeroPecaFormatado': '0701253-45.2025.8.02.0043.10.0002-26',
#    'dataNascimentoFormatada': '20/01/1975',
#    'dataExpedicaoFormatada': '13/10/2025'}],
#  'totalPages': 698,
#  'totalElements': 6973,
#  'last': False,
#  'first': True,
#  'numberOfElements': 10,
#  'sort': None,
#  'size': 10,
#  'number': 0}
